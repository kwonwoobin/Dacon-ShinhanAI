# %%
import re
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

year = 2023
df = pd.read_csv('./gaon_final_data.csv', index_col=0)
df = df.loc[df['year']==year]

# 노래제목 리스트
music_list = df['music'].unique().tolist()
music_list = music_list[:5]

# singer
for music in music_list:
    try:
        singer = df['singer'].loc[df['music']==music].tolist()[0]
    except:
        print('오류', music)


# 노래 id 딕셔너리 만들기 (key:노래id값, value:노래 제목)
id_dict={}
for idx, music in enumerate(music_list):
    

    id_dict[idx] = [music, singer]
    # time.sleep(1)

# %%
id_dict[0][0]
# Out:
# 'Ditto'

# %% [markdown]
# # 멜론 최종 코드드

# %%
import re
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

year = 2023
df = pd.read_csv('./gaon_final_data.csv', index_col=0)
df = df.loc[df['year']==year]

# 노래제목 리스트
music_list = df['music'].unique().tolist()
music_list = music_list[20:100]

# singer
for music in music_list:
    try:
        singer = df['singer'].loc[df['music']==music].tolist()[0]
    except:
        print('오류', music)


# 노래 id 딕셔너리 만들기 (key:노래id값, value:노래 제목)
id_dict={}
for music in music_list:
    singer = df['singer'].loc[df['music']==music].tolist()[0]

    # 가수이름 - 정규표현식으로 괄호 안의 내용 모두 삭제
    if singer.find('(') != -1:
        singer = re.sub('\([^)]*\)','', singer) 
    else:
        pass

    # 노래제목 - 정규표현식으로 괄호 안의 내용 모두 삭제
    if music.find('(') != -1:
        music = re.sub('\([^)]*\)','', music) 
    else:
        pass
    
    singer = singer.rstrip()
    music = music.rstrip()

    # 공백을 '+'로 바꿔줌
    music = music.replace(' ', '+')
    singer = singer.replace(' ', '+')

    # 특수문자 제거
    singer = re.sub('[-=+#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', "",singer)

    print(f'music:{music}, singer:{singer}')

    try:
        URL = f'https://www.melon.com/search/total/index.htm?q={music}+{singer}'
        header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}
        response = requests.get(URL,headers=header)
        time.sleep(1)
        soup = BeautifulSoup(response.text, 'html.parser')

        # try:
        links = soup.select_one('#frm_songList > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > div > input')
        #frm_songList > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > div > input

        music_id = links.attrs['value']
        print(music_id)
    except:
        print(f'오류, music:{music}')
        pass

    # +을 공백로 바꿔줌
    music = music.replace('+', ' ')
    singer = singer.replace('+', ' ')

    id_dict[music_id] = [music, singer]
    time.sleep(1)

# 노래 id만 있는 리스트 
id_list = list(id_dict.keys())



# 데이터 뽑아오기
result = []

for id in id_list:
    music = id_dict[id][0]
    singer = id_dict[id][1]
    print(f'현재 {music} 크롤링 중')

    try:
        URL_1 = f'https://www.melon.com/song/detail.htm?songId={id}'
        response_1 = requests.get(URL_1,headers=header)
        time.sleep(1)
        soup = BeautifulSoup(response_1.text, 'html.parser')

        # 발매일, 장르
        release_date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)').text
        category = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)').text
        

        # 좋아요 개수 json 접근
        URL_2 = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={id}'
        response_2 = requests.get(URL_2,headers=header).text
        time.sleep(1)
        like_json = json.loads(response_2)
        music_like = like_json['contsLike'][0]['SUMMCNT']

        # 코멘트 개수 json 접근
        URL_3 = f'https://www.melon.com/song/songReviewCnt.json?songId={id}'
        response_3 = requests.get(URL_3,headers=header).text
        time.sleep(1)

        comment_json = json.loads(response_3)
        comment_count = comment_json['reviewValidCmtCnt']

        temp = {
        'music':music,
        'singer':singer,
        'music_id':id,
        'release_date':release_date,
        'category':category,
        'music_like':music_like,
        'comment_count':comment_count,
    }

        result.append(temp)
    except:
        print(f'오류, music:{music}')
        pass


df = pd.DataFrame(result)
df.to_csv(f'./melon_data_{year}.csv')
# Out:
# music:FEARLESS, singer:LESSERAFIM
# 35009233
# music:그대를+알고, singer:송하예
# 35920493
# music:Rush+Hour, singer:크러쉬
# 35665282
# music:사랑인가+봐, singer:멜로망스
# 34657844
# music:Pink+Venom, singer:BLACKPINK
# 35542908
# music:잘가요, singer:주호
# 35890454
# music:해요, singer:안녕
# 35252996
# music:그때+그+순간+그대로, singer:WSG워너비
# 35383397
# music:TOMBOY, singer:아이들
# 34754292
# music:그라데이션, singer:10cm
# 35361345
# music:딱+10CM만, singer:10cm,BIGNaughty
# 35668899
# music:정이라고+하자, singer:BIGNaughty
# 34927767
# music:나의+X에게, singer:경서
# 34943312
# music:내가+아니라도, singer:주호
# 34787226
# music:미운오리새끼, singer:허성현
# 35957694
# music:자격지심, singer:BEO
# 35685439
# music:취중고백, singer:김민석
# 34431086
# music:오르트구름, singer:윤하
# 34270805
# music:눈++), singer:던말릭
# 35937397
# music:ELEVEN, singer:IVE
# 34349913
# music:That`s+Hilarious, singer:CharliePuth
# 34864406
# music:Say+I+Love+You, singer:우디
# 35953611
# music:다정히+내+이름을+부르면, singer:경서예지,전건호
# 33496587
# music:Snowman, singer:Sia
# 30717645
# music:첫사랑, singer:백아
# 31343875
# music:그댄+행복에+살텐데, singer:최유리
# 35958308
# music:보고싶었어, singer:WSG워너비
# 35383398
# music:모든+날,+모든+순간, singer:폴킴
# 30962526
# music:LOVE+me, singer:BEO
# 34875621
# music:눈이+오잖아, singer:이무진
# 34360855
# music:아픈+나를, singer:성시경
# 35963098
# music:그+겨울이+잠든+거리에서, singer:경서예지,전건호
# 35915690
# music:우리들의+블루스, singer:임영웅
# 34908740
# music:위하여, singer:그루비룸,릴보이,Blase,노윤하,Polodared,ChillinHomie,FleekyBang
# 35888868
# music:Stay, singer:TheKidLAROI,JustinBieber
# 33658563
# music:우린+그렇게+사랑해서, singer:강민경,잔나비
# 35669445
# music:주저하는+연인들을+위해, singer:잔나비
# 31666417
# music:밤하늘의+별을, singer:경서
# 33061995
# music:떠나보낼+준비해+둘걸+그랬어, singer:임한별
# 35730698
# music:빡+,+저스디스+), singer:던말릭
# 35957697
# music:내+기쁨은+너가+벤틀리를+끄는+거야, singer:김승민
# 34100776
# music:새벽에+걸려온+너의+전화는, singer:한동근
# 35484543
# music:도깨비불, singer:aespa
# 35238221
# music:나침반+), singer:KHAN
# 35937393
# music:다시+만날+수+있을까, singer:임영웅
# 35008524
# music:FOREVER+1, singer:소녀시대
# 35504734
# music:이+소설의+끝을+다시+써보려+해, singer:테이
# 35966218
# music:I+Don`t+Think+That+I+Like+Her, singer:CharliePuth
# 35640751
# music:That+That, singer:싸이
# 34997078
# music:WITCH, singer:이영지
# 35957700
# music:봄여름가을겨울, singer:BIGBANG
# 34845949
# music:Love+story, singer:볼빨간사춘기
# 34930368
# music:이제+나만+믿어요, singer:임영웅
# 32508053
# music:Dynamite, singer:방탄소년단
# 32872978
# music:드라마, singer:아이유
# 34481680
# music:흩어지지+않게, singer:엠씨더맥스
# 35897670
# music:Graduation, singer:NCTDREAM
# 35931533
# music:SNEAKERS, singer:ITZY
# 35413033
# music:Made+You+Look, singer:MeghanTrainor
# 35743320
# music:Unholy, singer:SamSmith,KimPetras
# 35663578
# music:Feel+My+Rhythm, singer:레드벨벳
# 34772475
# music:봄날, singer:방탄소년단
# 30244931
# music:Butter, singer:방탄소년단
# 33507137
# music:무지개, singer:임영웅
# 35008525
# music:strawberry+moon, singer:아이유
# 34101563
# music:첫+눈, singer:EXO
# 4352438
# music:London+Boy, singer:임영웅
# 35834583
# music:신호등, singer:이무진
# 33480898
# music:All+I+Want+For+Christmas+Is+You, singer:MariahCarey
# 오류, music:All+I+Want+For+Christmas+Is+You
# music:Madness, singer:문빈&산하
# 35992575
# music:스티커+사진, singer:21학번
# 35391594
# music:INVU, singer:태연
# 34626109
# music:DEJAVU, singer:이영지
# 35980450
# music:Santa+Tell+Me, singer:ArianaGrande
# 5475060
# music:Off+My+Face, singer:JustinBieber
# 33359309
# music:아버지, singer:임영웅
# 35008527
# music:Polaroid, singer:임영웅
# 35834583
# music:POP!, singer:나연
# 35333345
# music:Next+Level, singer:aespa
# 33487342
# music:내+손을+잡아, singer:아이유
# 3414749
# 현재 FEARLESS 크롤링 중
# 현재 그대를 알고 크롤링 중
# 현재 Rush Hour 크롤링 중
# 현재 사랑인가 봐 크롤링 중
# 현재 Pink Venom 크롤링 중
# 현재 잘가요 크롤링 중
# 현재 해요 크롤링 중
# 현재 그때 그 순간 그대로 크롤링 중
# 현재 TOMBOY 크롤링 중
# 현재 그라데이션 크롤링 중
# 현재 딱 10CM만 크롤링 중
# 현재 정이라고 하자 크롤링 중
# 현재 나의 X에게 크롤링 중
# 현재 내가 아니라도 크롤링 중
# 현재 미운오리새끼 크롤링 중
# 현재 자격지심 크롤링 중
# 현재 취중고백 크롤링 중
# 현재 오르트구름 크롤링 중
# 현재 눈  ) 크롤링 중
# 현재 ELEVEN 크롤링 중
# 현재 That`s Hilarious 크롤링 중
# 현재 Say I Love You 크롤링 중
# 현재 다정히 내 이름을 부르면 크롤링 중
# 현재 Snowman 크롤링 중
# 현재 첫사랑 크롤링 중
# 현재 그댄 행복에 살텐데 크롤링 중
# 현재 보고싶었어 크롤링 중
# 현재 모든 날, 모든 순간 크롤링 중
# 현재 LOVE me 크롤링 중
# 현재 눈이 오잖아 크롤링 중
# 현재 아픈 나를 크롤링 중
# 현재 그 겨울이 잠든 거리에서 크롤링 중
# 현재 우리들의 블루스 크롤링 중
# 현재 위하여 크롤링 중
# 현재 Stay 크롤링 중
# 현재 우린 그렇게 사랑해서 크롤링 중
# 현재 주저하는 연인들을 위해 크롤링 중
# 현재 밤하늘의 별을 크롤링 중
# 현재 떠나보낼 준비해 둘걸 그랬어 크롤링 중
# 현재 빡 , 저스디스 ) 크롤링 중
# 현재 내 기쁨은 너가 벤틀리를 끄는 거야 크롤링 중
# 현재 새벽에 걸려온 너의 전화는 크롤링 중
# 현재 도깨비불 크롤링 중
# 현재 나침반 ) 크롤링 중
# 현재 다시 만날 수 있을까 크롤링 중
# 현재 FOREVER 1 크롤링 중
# 현재 이 소설의 끝을 다시 써보려 해 크롤링 중
# 현재 I Don`t Think That I Like Her 크롤링 중
# 현재 That That 크롤링 중
# 현재 WITCH 크롤링 중
# 현재 봄여름가을겨울 크롤링 중
# 현재 Love story 크롤링 중
# 현재 이제 나만 믿어요 크롤링 중
# 현재 Dynamite 크롤링 중
# 현재 드라마 크롤링 중
# 현재 흩어지지 않게 크롤링 중
# 현재 Graduation 크롤링 중
# 현재 SNEAKERS 크롤링 중
# 현재 Made You Look 크롤링 중
# 현재 Unholy 크롤링 중
# 현재 Feel My Rhythm 크롤링 중
# 현재 봄날 크롤링 중
# 현재 Butter 크롤링 중
# 현재 무지개 크롤링 중
# 현재 strawberry moon 크롤링 중
# 현재 첫 눈 크롤링 중
# 현재 Polaroid 크롤링 중
# 현재 All I Want For Christmas Is You 크롤링 중
# 현재 Madness 크롤링 중
# 현재 스티커 사진 크롤링 중
# 현재 INVU 크롤링 중
# 현재 DEJAVU 크롤링 중
# 현재 Santa Tell Me 크롤링 중
# 현재 Off My Face 크롤링 중
# 현재 아버지 크롤링 중
# 현재 POP! 크롤링 중
# 현재 Next Level 크롤링 중
# 현재 내 손을 잡아 크롤링 중

# %% [markdown]
# ## 노래의 id값 먼저 뽑아오기

# %%
music_list
# Out:
# ['Dancing Queen', '사랑은 이렇게', '되돌리다', '카페인', '매력있어']

# %%
import re

id_dict={}
for music in music_list:
    singer = df['singer'].loc[df['music']==music].tolist()[0]
  
    # 정규표현식으로 괄호 안의 내용 모두 삭제
    if singer.find('(') != -1:
        singer = re.sub(' \([^)]*\)','', singer) 
    # 괄호 없는 경우는 변수에 가수 이름 그대로 저장
    else:
        # singer_bracket = singer
        pass

    # 공백을 '+'로 바꿔줌
    music = music.replace(' ', '+')
    singer = singer.replace(' ', '+')


    URL = f'https://www.melon.com/search/total/index.htm?q={singer}+{music}'
    header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}
    response = requests.get(URL,headers=header)
    soup = BeautifulSoup(response.text, 'html.parser')

    links = soup.select_one('#frm_songList > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > div > input')
    music_id = links.attrs['value']

    # except:
    #     links = soup.select_one('#frm_searchSong > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > div > input')
    #     music_id = links.attrs['value']

    # finally:
        # '+'를 다시 공백으로 바꿔줌
    music = music.replace('+', ' ')
    singer = singer.replace('+', ' ')

    id_dict[music_id] = music
    time.sleep(1)

# %%
id_dict
# Out:
# {'35945927': 'OMG',
#  '34819473': '사건의 지평선',
#  '35454426': 'Hype boy',
#  '35937396': 'NOT SORRY',
#  '35931532': 'Candy',
#  '35729104': 'ANTIFRAGILE',
#  '35546497': 'After LIKE',
#  '35454425': 'Attention',
#  '35730562': 'Nxde',
#  '35595136': '새삥',
#  '35888871': '마이웨이',
#  '34847378': 'LOVE DIVE',
#  '35643794': 'Monologue',
#  '4446485': '너의 모든 순간',
#  '35485544': 'Cookie',
#  '35849863': 'Dreamers',
#  '35640077': 'Shut Down',
#  '35876006': 'WHEN I MOVE',
#  '34061322': '사랑은 늘 도망가',
#  '35009233': 'FEARLESS',
#  '35920493': '그대를 알고',
#  '35665282': 'Rush Hour',
#  '34657844': '사랑인가 봐',
#  '35542908': 'Pink Venom',
#  '35890454': '잘가요',
#  '35252996': '해요',
#  '35383397': '그때 그 순간 그대로',
#  '34754292': 'TOMBOY',
#  '35361345': '그라데이션',
#  '35668899': '딱 10CM만',
#  '34927767': '정이라고 하자',
#  '34943312': '나의 X에게',
#  '34787226': '내가 아니라도',
#  '35957694': '미운오리새끼',
#  '35685439': '자격지심',
#  '34431086': '취중고백',
#  '34270805': '오르트구름',
#  '35937397': '눈  )',
#  '34349913': 'ELEVEN',
#  '34864406': 'That`s Hilarious',
#  '35953611': 'Say I Love You',
#  '33496587': '다정히 내 이름을 부르면',
#  '30717645': 'Snowman',
#  '31343875': '첫사랑',
#  '35958308': '그댄 행복에 살텐데',
#  '35383398': '보고싶었어',
#  '30962526': '모든 날, 모든 순간',
#  '34875621': 'LOVE me',
#  '34360855': '눈이 오잖아',
#  '35963098': '아픈 나를',
#  '35915690': '그 겨울이 잠든 거리에서',
#  '34908740': '우리들의 블루스',
#  '35888868': '위하여',
#  '33658563': 'Stay',
#  '35669445': '우린 그렇게 사랑해서',
#  '31666417': '주저하는 연인들을 위해',
#  '33061995': '밤하늘의 별을',
#  '35730698': '떠나보낼 준비해 둘걸 그랬어',
#  '35957697': '빡 , 저스디스 )',
#  '34100776': '내 기쁨은 너가 벤틀리를 끄는 거야',
#  '35484543': '새벽에 걸려온 너의 전화는',
#  '35238221': '도깨비불',
#  '35937393': '나침반 )',
#  '35008524': '다시 만날 수 있을까',
#  '35504734': 'FOREVER 1',
#  '35966218': '이 소설의 끝을 다시 써보려 해',
#  '35640751': 'I Don`t Think That I Like Her',
#  '34997078': 'That That',
#  '35957700': 'WITCH',
#  '34845949': '봄여름가을겨울',
#  '34930368': 'Love story',
#  '32508053': '이제 나만 믿어요',
#  '32872978': 'Dynamite',
#  '34481680': '드라마',
#  '35897670': '흩어지지 않게',
#  '35931533': 'Graduation',
#  '35413033': 'SNEAKERS',
#  '35743320': 'Made You Look',
#  '35663578': 'Unholy',
#  '34772475': 'Feel My Rhythm',
#  '30244931': '봄날',
#  '33507137': 'Butter',
#  '35008525': '무지개',
#  '34101563': 'strawberry moon',
#  '4352438': '첫 눈',
#  '35834583': 'Polaroid',
#  '33480898': 'All I Want For Christmas Is You',
#  '35992575': 'Madness',
#  '35391594': '스티커 사진',
#  '34626109': 'INVU',
#  '35980450': 'DEJAVU',
#  '5475060': 'Santa Tell Me',
#  '33359309': 'Off My Face',
#  '35008527': '아버지',
#  '35333345': 'POP!',
#  '33487342': 'Next Level',
#  '3414749': '내 손을 잡아',
#  '36014317': 'Beautiful Liar',
#  '36034936': 'VIBE',
#  '8037843': 'Dangerously',
#  '36010484': '눈의 꽃',
#  '32061975': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#  '33666269': 'Permission to Dance',
#  '36033536': '마지막 사랑',
#  '36040619': '사랑해도 될까요',
#  '36026650': '가슴으로 운다',
#  '36040047': 'Love War',
#  '36046168': '니 번호가 뜨는 일',
#  '35993850': 'Stamp On It',
#  '418168': '희재',
#  '36065180': '당신을 만나',
#  '36062700': '네가 보고 싶은 건 자연스러운 거겠지',
#  '36078777': 'Sugar Rush Ride',
#  '35667692': '그중에 그대를 만나',
#  '36076998': '꿈의 거처',
#  '35690912': '나의 목소리로',
#  '36048470': '손을 마주 잡고',
#  '36079879': 'Ay-Yo',
#  '36081382': '친구로 지내다 보면',
#  '36078776': 'Devil by the Window',
#  '36100714': '혼자서 걸어요',
#  '36078780': '네버랜드를 떠나며',
#  '36078779': 'Tinnitus',
#  '36078778': 'Happy Fools',
#  '34929349': 'The Drum',
#  '36110996': '파이팅 해야지',
#  '36110998': '7시에 들어줘',
#  '36110997': 'LUNCH',
#  '36109370': '우리가 맞다는 대답을 할 거예요',
#  '35911191': 'Kill Bill',
#  '36105549': 'Poppy',
#  '36105548': 'Teddy Bear',
#  '36139862': 'Killer',
#  '36136159': 'Yesterday',
#  '36124331': 'Endless',
#  '36133539': '지금 고백합니다',
#  '31927275': '한 페이지가 될 수 있게',
#  '35331586': 'Left and Right',
#  '36182838': 'ROAR',
#  '36181007': '풍등',
#  '36180700': '심',
#  '35535827': 'NIGHT DANCER',
#  '36001290': '건물 사이에 피어난 장미',
#  '36191613': '이젠 안녕',
#  '36082135': '세상에 없는 계절',
#  '36206208': '사랑하기 싫어',
#  '36205780': '너와 함께',
#  '36216989': '걸음을 멈추는 날',
#  '36241824': 'on the street',
#  '36224655': '사랑이라 믿었던 것들은',
#  '36235518': '나비무덤',
#  '36247336': 'O',
#  '36145589': 'CHRISTIAN',
#  '36235272': '혼자가 아닌 나',
#  '36245034': 'Nostalgia',
#  '36269721': 'Rover',
#  '36294096': 'Set Me Free Pt.2',
#  '36265974': 'Expectations',
#  '36263564': 'SET ME FREE',
#  '36254943': '55',
#  '36313117': 'Like Crazy',
#  '36291745': '결국엔 너에게 닿아서',
#  '36294584': '너를 보는게 지친 하루에',
#  '36296186': '되돌리다',
#  '36266615': 'Love Me Like This',
#  '36313115': 'Face-off',
#  '36318125': 'Kitsch',
#  '36312416': '밤이 무서워요',
#  '36331121': '꽃',
#  '3753304': '벚꽃 엔딩',
#  '4579468': '봄 사랑 벚꽃 말고',
#  '36266614': 'Young, Dumb, Stupid',
#  '36303189': '아모르 파티',
#  '5650996': 'Sour & Sweet',
#  '36337593': 'Zero',
#  '36351997': '사람 Pt.2',
#  '36322781': 'That’s Not How This Works',
#  '36334401': '사랑하지 않아서 그랬어',
#  '36325563': '발걸음',
#  '31709523': 'I AM',
#  '36206259': 'Cupid',
#  '36344975': 'Say My Name',
#  '36356992': 'Blue Blood',
#  '36348051': '가질 수 없는 너',
#  '36338239': '빙글빙글',
#  '36356994': 'Lips',
#  '36374470': 'Perfume',
#  '36371558': 'FRIEND THE END',
#  '36371557': 'Chase Love Hard',
#  '36365073': '빛이 나는 너에게',
#  '36371560': '사랑이 이별이 돼 가는 모습이',
#  '30633420': 'Ai Wo Tsutaetaidatoka',
#  '36388567': '해금',
#  '36350347': '다시 사랑한다면',
#  '36391236': '손오공',
#  '36391235': 'F*ck My Life',
#  '36382580': '헤어지자 말해요',
#  '36391239': '먼지',
#  '36391240': 'April shower',
#  '36391237': 'Fire',
#  '36391238': 'I Don`t Understand But I Luv U',
#  '36391318': '나의 마음에',
#  '36359275': 'KNOCK',
#  '35738070': 'When I Get Old',
#  '36411342': 'UNFORGIVEN',
#  '36404853': '물론',
#  '36414423': '나의 바람',
#  '36394038': 'Heaven',
#  '36410735': '안녕이라고 말하지마',
#  '36411344': '이브, 프시케 그리고 푸른 수염의 아내',
#  '36411343': 'No-Return'}

# %%
id_list = list(id_dict.keys())
id_list = id_list[:5]

# %%
result = []

for id in id_list:
    music = id_dict[id]

    URL_1 = f'https://www.melon.com/song/detail.htm?songId={id}'
    response_1 = requests.get(URL_1,headers=header)
    soup = BeautifulSoup(response_1.text, 'html.parser')

    # 발매일, 장르
    release_date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)').text
    category = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)').text
    

    # 좋아요 개수 json 접근
    URL_2 = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={id}'
    response_2 = requests.get(URL_2,headers=header).text

    like_json = json.loads(response_2)
    music_like = like_json['contsLike'][0]['SUMMCNT']

    # 코멘트 개수 json 접근
    URL_3 = f'https://www.melon.com/song/songReviewCnt.json?songId={id}'
    response_3 = requests.get(URL_3,headers=header).text

    comment_json = json.loads(response_3)
    comment_count = comment_json['reviewValidCmtCnt']


    print(f'id:{id}, release_date:{release_date}, category:{category} music_like:{music_like}, comment_count:{comment_count}')

    temp = {
    'music':music,
    'music_id':id,
    'release_date':release_date,
    'category':category,
    'music_like':music_like,
    'comment_count':comment_count,
}

    result.append(temp)

    df = pd.DataFrame(result)
    df
# df.to_csv(f'./melon_data_test2.csv')
# time.sleep(1)
# Out:
# id:35945927, release_date:2022.12.19, category:댄스 music_like:254724, comment_count:3086
# id:34819473, release_date:2022.03.30, category:록/메탈 music_like:300079, comment_count:3148
# id:35454426, release_date:2022.08.01, category:댄스 music_like:261042, comment_count:2052
# id:35937396, release_date:2022.12.17, category:랩/힙합 music_like:94572, comment_count:609
# id:35931532, release_date:2022.12.16, category:댄스 music_like:149063, comment_count:7251

# %%
id = '35937396'
# 좋아요 가져오기위해 json으로 접근
URL_2 = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={id}'
response_2 = requests.get(URL_2,headers=header).text

like_json = json.loads(response_2)
music_like = like_json['contsLike'][0]['SUMMCNT']
music_like
# Out:
# 94562

# %%
import re

id = '35945927'
# 뮤비 고유 code 가져오기 - 상세페이지에 뮤비 없는 경우 pass
try:
    header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}
    
    response = requests.get(URL_3,headers=header)
    soup = BeautifulSoup(response.text, 'html.parser')

    movie = soup.select_one('#conts > div.section_movie > div.service_list_video.type03.d_video_list > ul > li > div.thumb > a')
    movie = movie.attrs['href']
    movie = re.sub('[a-zA-z:.(\')]', '', movie)
    movie_id = movie.split(', ')[1]

    time.sleep(1)
    # 뮤비 고유 코드 이용해서 json 접근해서 뮤비 뷰수와 좋아요 가져오기
    URL_4 = f'https://www.melon.com/commonlike/getMvLikeWithReadCnt.json?contsIds={id}'
    response_3 = requests.get(URL_4, headers=header).text
    movie_json = json.loads(response_3)
    movie_like = movie_json['contsLike'][0]['LOVECNT']
    movie_views = movie_json['contsLike'][0]['READCNT']
    time.sleep(1)

except:
    print(f'뮤비 없음 id:', id)
# Out:
# 뮤비 없음 id: 35945927
# C:\Users\bin\AppData\Local\Temp\ipykernel_33324\1386413818.py:9: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(response.text, 'html.parser')

# %%
import re

id = '35945927'
# 뮤비 고유 code 가져오기 - 상세페이지에 뮤비 없는 경우 pass
try:
    header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}
    
    response = requests.get(URL_3,headers=header)
    soup = BeautifulSoup(response.text, 'html.parser')

    movie = soup.select_one('#conts > div.section_movie > div.service_list_video.type03.d_video_list > ul > li > div.thumb > a')
    movie = movie.attrs['href']
    movie = re.sub('[a-zA-z:.(\')]', '', movie)
    movie_id = movie.split(', ')[1]

    time.sleep(1)
    # 뮤비 고유 코드 이용해서 json 접근해서 뮤비 뷰수와 좋아요 가져오기
    URL_4 = f'https://www.melon.com/commonlike/getMvLikeWithReadCnt.json?contsIds={id}'
    response_3 = requests.get(URL_4, headers=header).text
    movie_json = json.loads(response_3)
    movie_like = movie_json['contsLike'][0]['LOVECNT']
    movie_views = movie_json['contsLike'][0]['READCNT']
    time.sleep(1)

except:
    print(f'뮤비 없음 id:', id)

# %%
id = '35945927'
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}

response = requests.get(URL_3,headers=header)
soup = BeautifulSoup(response.text, 'html.parser')

movie = soup.select('#conts > div.section_movie > div.service_list_video.type03.d_video_list > ul > li:nth-child(1) > div.thumb > a')

# movie = soup.select_one('#conts > div.section_movie > div.service_list_video.type03.d_video_list > ul > li > div.thumb > a')
# movie = movie.attrs['href']
# movie = re.sub('[a-zA-z:.(\')]', '', movie)
# movie_id = movie.split(', ')[1]
print(movie)
# Out:
# []
# C:\Users\bin\AppData\Local\Temp\ipykernel_33324\1117603341.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(response.text, 'html.parser')
