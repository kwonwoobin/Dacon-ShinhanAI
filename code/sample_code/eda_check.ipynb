# %%
import pandas as pd
# from matplotlib import pyplot as plt
# import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from matplotlib import pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ### gaon 데이터

# %%
data = pd.read_csv('new_gaon_data.csv', index_col=0)
data
# Out:
#        year  week_num  start_date    end_date  rank     music       singer  \
# 0      2013        11  2013.03.10  2013.03.16     1       거북이          다비치
# 1      2013        11  2013.03.10  2013.03.16     2        눈꽃           거미
# 2      2013        11  2013.03.10  2013.03.16     3        눈꽃           거미
# 3      2013        11  2013.03.10  2013.03.16     4   있다 없으니까        씨스타19
# 4      2013        11  2013.03.10  2013.03.16     5     라면인건가    AKMU (악뮤)
# ...     ...       ...         ...         ...   ...       ...          ...
# 53695  2023        15  2023.04.09  2023.04.15   100  The Drum  Alan Walker
# 53696  2023         4  2023.01.22  2023.01.28    99  Love War    YENA(최예나)
# 53697  2023         5  2023.01.29  2023.02.04    99  Love War    YENA(최예나)
# 53698  2023         4  2023.01.22  2023.01.28   100  The Drum  Alan Walker
# 53699  2023         5  2023.01.29  2023.02.04   100  The Drum  Alan Walker
#
#                              album
# 0             Mystic Ballad Part 1
# 1          그 겨울, 바람이 분다 OST Part 3
# 2          그 겨울, 바람이 분다 OST Part 3
# 3                          있다 없으니까
# 4      SBS K팝 스타 시즌2 TOP 10 Part 1
# ...                            ...
# 53695                     The Drum
# 53696                     Love War
# 53697                     Love War
# 53698                     The Drum
# 53699                     The Drum
#
# [53700 rows x 8 columns]

# %%
df = data.copy()

# %%
#pd.set_option('display.max_rows', None)

# %%
a=data.groupby(['music'])['music'].count().to_dict()  # music끼리 묶어서 세어보기
#b=data.groupby(['music'])['music'].count().to_dict()

# %%
test_df1 = pd.DataFrame.from_dict(a, orient='index', columns=['total_counts'])
#test_df2 = pd.DataFrame.from_dict(b, orient='index')
test_df1
# Out:
#                           total_counts
# #불편해)                               25
# #첫사랑                                12
# #화이트 스타일                            23
# %%(응응)                              29
# (Bonus Track) Voice Mail             1
# ...                                ...
# 희맨사항                                10
# 희재                                  15
# 흰눈                                  25
# 히치하이킹                               10
# 힘든 건 사랑이 아니다                        49
#
# [3194 rows x 1 columns]

# %%
test_df1.reset_index(inplace=True)

# %%
# 인덱스 만들어주기
test_df1
# Out:
#                          index  total_counts
# 0                        #불편해)            25
# 1                         #첫사랑            12
# 2                     #화이트 스타일            23
# 3                       %%(응응)            29
# 4     (Bonus Track) Voice Mail             1
# ...                        ...           ...
# 3189                      희맨사항            10
# 3190                        희재            15
# 3191                        흰눈            25
# 3192                     히치하이킹            10
# 3193              힘든 건 사랑이 아니다            49
#
# [3194 rows x 2 columns]

# %%
#컬럼명 바꾸기(music) -> 위에 index 컬럼을 music으로 변경
test_df1=test_df1.rename(columns={'index':'music'})
test_df1
# Out:
#                          music  total_counts
# 0                        #불편해)            25
# 1                         #첫사랑            12
# 2                     #화이트 스타일            23
# 3                       %%(응응)            29
# 4     (Bonus Track) Voice Mail             1
# ...                        ...           ...
# 3189                      희맨사항            10
# 3190                        희재            15
# 3191                        흰눈            25
# 3192                     히치하이킹            10
# 3193              힘든 건 사랑이 아니다            49
#
# [3194 rows x 2 columns]

# %%
test_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3194 entries, 0 to 3193
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   music         3194 non-null   object
#  1   total_counts  3194 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 50.0+ KB

# %%
# merge해서 데이터 합쳐주기
result = pd.merge(df, test_df1, on='music')

# %%
result
# Out:
#        year  week_num  start_date    end_date  rank     music       singer  \
# 0      2013        11  2013.03.10  2013.03.16     1       거북이          다비치
# 1      2013        12  2013.03.17  2013.03.23     5       거북이          다비치
# 2      2013        12  2013.03.17  2013.03.23    12       거북이          다비치
# 3      2013        13  2013.03.24  2013.03.30    12       거북이          다비치
# 4      2013        12  2013.03.17  2013.03.23    16       거북이          다비치
# ...     ...       ...         ...         ...   ...       ...          ...
# 53695  2023         2  2023.01.08  2023.01.14   100  The Drum  Alan Walker
# 53696  2023         3  2023.01.15  2023.01.21   100  The Drum  Alan Walker
# 53697  2023        15  2023.04.09  2023.04.15   100  The Drum  Alan Walker
# 53698  2023         4  2023.01.22  2023.01.28   100  The Drum  Alan Walker
# 53699  2023         5  2023.01.29  2023.02.04   100  The Drum  Alan Walker
#
#                       album  total_counts
# 0      Mystic Ballad Part 1            23
# 1      Mystic Ballad Part 1            23
# 2      Mystic Ballad Part 1            23
# 3      Mystic Ballad Part 1            23
# 4      Mystic Ballad Part 1            23
# ...                     ...           ...
# 53695              The Drum            15
# 53696              The Drum            15
# 53697              The Drum            15
# 53698              The Drum            15
# 53699              The Drum            15
#
# [53700 rows x 9 columns]

# %%
# $$가 인식이 안돼서 replace 함

df.replace({'music': {'ON IT + BO$$': 'ON IT + BOSS'}},inplace=True)

# %%
# music 컬럼에서 갯수 세고 상위 100개 정렬

music_100 = df['music'].value_counts().head(100).sort_values()
music_100.plot.barh(figsize=(10,22), title="상위 music 100개")
# Out:
# <AxesSubplot:title={'center':'상위 music 100개'}>

# %%
# singer 칼럼에서 갯수 세고 상위 100개 정렬

singer_100 = df['singer'].value_counts().head(100).sort_values()
singer_100.plot.barh(figsize=(10,22), title="상위 가수 100명")
# Out:
# <AxesSubplot:title={'center':'상위 가수 100명'}>

# %% [markdown]
# ### melon

# %%
melon_2015 = pd.read_csv('C:/Users/zzzzz/신한ai/data/melon_2015_2023/melon_2015.csv')
melon_2016 = pd.read_csv('C:/Users/zzzzz/신한ai/data/melon_2015_2023/melon_2016.csv')
melon_2017 = pd.read_csv('C:/Users/zzzzz/신한ai/data/melon_2015_2023/melon_2017.csv')

# %%
melon_2015
# Out:
#         music              singer release_date category  music_like  \
# 0         팔베개            소유, 기리보이   2015.01.15     랩/힙합       49679
# 1          표적                  신화   2015.02.26       댄스       21363
# 2         목소리                  노을   2015.01.08      발라드       57220
# 3         위아래                EXID   2014.08.27       댄스       76205
# 4        이별공식            빅스(VIXX)   2015.02.24       댄스       35291
# ..        ...                 ...          ...      ...         ...
# 241   어느 멋진 날  정용화(Jung Yong Hwa)   2018.11.07      발라드         321
# 242       드라마              나인 뮤지스   2014.08.07    국내드라마          46
# 243   My Love                 에디킴   2015.01.21   포크/블루스       21869
# 244   두 여자의 방                 다비치   2015.01.21      발라드        9318
# 245  행복해서 미안해                 다비치   2015.01.21      발라드       28122
#
#      movie_like  movie_views
# 0           NaN          NaN
# 1        3796.0     413254.0
# 2         488.0     213821.0
# 3        3486.0    5814486.0
# 4        3601.0     323028.0
# ..          ...          ...
# 241         NaN          NaN
# 242         NaN          NaN
# 243       538.0     111081.0
# 244         NaN          NaN
# 245      1068.0     201106.0
#
# [246 rows x 7 columns]

# %% [markdown]
# ### 2016 melon 장르 카테고리

# %%
plt.figure(figsize=(10,10))

plt.title('2016 melon 장르')

melon_2016['category'].value_counts().plot.pie(autopct = '%1.1f%%', 
                                         textprops = {'fontsize' : 8})

plt.show()

# %%
melon_data = pd.read_csv('C:/Users/zzzzz/신한ai/data/melon_data.csv',index_col=0)
melon_data
# Out:
#                               music        singer release_date    category  \
# 0                             모노드라마       허각, 유승우   2013.02.05         발라드
# 1                             라면인건가          AKMU   2013.02.17      포크/블루스
# 2                           있다 없으니까         씨스타19   2013.01.31          댄스
# 3                                눈꽃            거미   2013.02.27  발라드, 국내드라마
# 4                               거북이           다비치   2013.03.04         발라드
# ...                             ...           ...          ...         ...
# 3838                         Cookie      NewJeans   2022.08.01          댄스
# 3839                     Teddy Bear   STAYC(스테이씨)   2023.02.14          댄스
# 3840                       너의 모든 순간           성시경   2014.02.12  발라드, 국내드라마
# 3841                             풍등           이찬원   2023.02.20    성인가요/트로트
# 3842  I Don`t Think That I Like Her  Charlie Puth   2022.10.07         POP
#
#      music_like movie_like movie_views  Unnamed: 0
# 0         87466      181.0    220476.0         NaN
# 1         36725        NaN         NaN         NaN
# 2         56138      441.0    629192.0         NaN
# 3         52474        NaN         NaN         NaN
# 4         92257      587.0    208556.0         NaN
# ...         ...        ...         ...         ...
# 3838     133714     3171.0    152708.0         NaN
# 3839      84132      707.0     64019.0         NaN
# 3840     260608        NaN         NaN         NaN
# 3841      12873     3770.0     20260.0         NaN
# 3842     157877        NaN         NaN         NaN
#
# [3843 rows x 8 columns]

# %%
melon_data = melon_data.drop(columns='Unnamed: 0')

# %%
melon_data
# Out:
#                               music        singer release_date    category  \
# 0                             모노드라마       허각, 유승우   2013.02.05         발라드
# 1                             라면인건가          AKMU   2013.02.17      포크/블루스
# 2                           있다 없으니까         씨스타19   2013.01.31          댄스
# 3                                눈꽃            거미   2013.02.27  발라드, 국내드라마
# 4                               거북이           다비치   2013.03.04         발라드
# ...                             ...           ...          ...         ...
# 3838                         Cookie      NewJeans   2022.08.01          댄스
# 3839                     Teddy Bear   STAYC(스테이씨)   2023.02.14          댄스
# 3840                       너의 모든 순간           성시경   2014.02.12  발라드, 국내드라마
# 3841                             풍등           이찬원   2023.02.20    성인가요/트로트
# 3842  I Don`t Think That I Like Her  Charlie Puth   2022.10.07         POP
#
#      music_like movie_like movie_views
# 0         87466      181.0    220476.0
# 1         36725        NaN         NaN
# 2         56138      441.0    629192.0
# 3         52474        NaN         NaN
# 4         92257      587.0    208556.0
# ...         ...        ...         ...
# 3838     133714     3171.0    152708.0
# 3839      84132      707.0     64019.0
# 3840     260608        NaN         NaN
# 3841      12873     3770.0     20260.0
# 3842     157877        NaN         NaN
#
# [3843 rows x 7 columns]

# %%
melon_data = melon_data.fillna(0)

# %%
melon_data.isnull().sum()
# Out:
# music           0
# singer          0
# release_date    0
# category        0
# music_like      0
# movie_like      0
# movie_views     0
# dtype: int64

# %%
melon_data['new_category'] = melon_data.category.str.split(", 국내드라마").str[0]
melon_data
# Out:
#                               music        singer release_date    category  \
# 0                             모노드라마       허각, 유승우   2013.02.05         발라드
# 1                             라면인건가          AKMU   2013.02.17      포크/블루스
# 2                           있다 없으니까         씨스타19   2013.01.31          댄스
# 3                                눈꽃            거미   2013.02.27  발라드, 국내드라마
# 4                               거북이           다비치   2013.03.04         발라드
# ...                             ...           ...          ...         ...
# 3838                         Cookie      NewJeans   2022.08.01          댄스
# 3839                     Teddy Bear   STAYC(스테이씨)   2023.02.14          댄스
# 3840                       너의 모든 순간           성시경   2014.02.12  발라드, 국내드라마
# 3841                             풍등           이찬원   2023.02.20    성인가요/트로트
# 3842  I Don`t Think That I Like Her  Charlie Puth   2022.10.07         POP
#
#      music_like movie_like movie_views new_category
# 0         87466      181.0    220476.0          발라드
# 1         36725          0           0       포크/블루스
# 2         56138      441.0    629192.0           댄스
# 3         52474          0           0          발라드
# 4         92257      587.0    208556.0          발라드
# ...         ...        ...         ...          ...
# 3838     133714     3171.0    152708.0           댄스
# 3839      84132      707.0     64019.0           댄스
# 3840     260608          0           0          발라드
# 3841      12873     3770.0     20260.0     성인가요/트로트
# 3842     157877          0           0          POP
#
# [3843 rows x 8 columns]

# %%
melon_data['OST'] = None

# %%
#category에 국내드라마 가 있으면 , drama 컬럼에 1을 줌
#category에 국내드라마 가 없으면 , drama 컬럼에 0을 줌

melon_data.loc[melon_data['category'].str.contains('국내드라마') == True, 'OST'] = 1

melon_data.loc[melon_data['category'].str.contains('국내드라마') == False, 'OST'] = 0

# %%
melon_data.drop(columns=['category'], inplace=True)

#이전 카테고리 삭제

# %%
melon_data
# Out:
#                               music        singer release_date music_like  \
# 0                             모노드라마       허각, 유승우   2013.02.05      87466
# 1                             라면인건가          AKMU   2013.02.17      36725
# 2                           있다 없으니까         씨스타19   2013.01.31      56138
# 3                                눈꽃            거미   2013.02.27      52474
# 4                               거북이           다비치   2013.03.04      92257
# ...                             ...           ...          ...        ...
# 3838                         Cookie      NewJeans   2022.08.01     133714
# 3839                     Teddy Bear   STAYC(스테이씨)   2023.02.14      84132
# 3840                       너의 모든 순간           성시경   2014.02.12     260608
# 3841                             풍등           이찬원   2023.02.20      12873
# 3842  I Don`t Think That I Like Her  Charlie Puth   2022.10.07     157877
#
#      movie_like movie_views new_category OST
# 0         181.0    220476.0          발라드   0
# 1             0           0       포크/블루스   0
# 2         441.0    629192.0           댄스   0
# 3             0           0          발라드   1
# 4         587.0    208556.0          발라드   0
# ...         ...         ...          ...  ..
# 3838     3171.0    152708.0           댄스   0
# 3839      707.0     64019.0           댄스   0
# 3840          0           0          발라드   1
# 3841     3770.0     20260.0     성인가요/트로트   0
# 3842          0           0          POP   0
#
# [3843 rows x 8 columns]

# %%
melon_data[melon_data['new_category']=='-']
# Out:
#       music  singer  release_date  music_like  movie_like  movie_views  \
# 2405  music  singer  release_date  music_like  movie_like  movie_views
#
#      new_category OST
# 2405     category   0

# %%
melon_data.drop(index=2405, axis=0, inplace=True)
melon_data
# Out:
#                               music        singer release_date music_like  \
# 0                             모노드라마       허각, 유승우   2013.02.05      87466
# 1                             라면인건가          AKMU   2013.02.17      36725
# 2                           있다 없으니까         씨스타19   2013.01.31      56138
# 3                                눈꽃            거미   2013.02.27      52474
# 4                               거북이           다비치   2013.03.04      92257
# ...                             ...           ...          ...        ...
# 3838                         Cookie      NewJeans   2022.08.01     133714
# 3839                     Teddy Bear   STAYC(스테이씨)   2023.02.14      84132
# 3840                       너의 모든 순간           성시경   2014.02.12     260608
# 3841                             풍등           이찬원   2023.02.20      12873
# 3842  I Don`t Think That I Like Her  Charlie Puth   2022.10.07     157877
#
#      movie_like movie_views new_category OST
# 0         181.0    220476.0          발라드   0
# 1             0           0       포크/블루스   0
# 2         441.0    629192.0           댄스   0
# 3             0           0          발라드   1
# 4         587.0    208556.0          발라드   0
# ...         ...         ...          ...  ..
# 3838     3171.0    152708.0           댄스   0
# 3839      707.0     64019.0           댄스   0
# 3840          0           0          발라드   1
# 3841     3770.0     20260.0     성인가요/트로트   0
# 3842          0           0          POP   0
#
# [3842 rows x 8 columns]

# %%
melon_data.reset_index(drop=True,inplace=True)
melon_data
# Out:
#                               music        singer release_date music_like  \
# 0                             모노드라마       허각, 유승우   2013.02.05      87466
# 1                             라면인건가          AKMU   2013.02.17      36725
# 2                           있다 없으니까         씨스타19   2013.01.31      56138
# 3                                눈꽃            거미   2013.02.27      52474
# 4                               거북이           다비치   2013.03.04      92257
# ...                             ...           ...          ...        ...
# 3837                         Cookie      NewJeans   2022.08.01     133714
# 3838                     Teddy Bear   STAYC(스테이씨)   2023.02.14      84132
# 3839                       너의 모든 순간           성시경   2014.02.12     260608
# 3840                             풍등           이찬원   2023.02.20      12873
# 3841  I Don`t Think That I Like Her  Charlie Puth   2022.10.07     157877
#
#      movie_like movie_views new_category OST
# 0         181.0    220476.0          발라드   0
# 1             0           0       포크/블루스   0
# 2         441.0    629192.0           댄스   0
# 3             0           0          발라드   1
# 4         587.0    208556.0          발라드   0
# ...         ...         ...          ...  ..
# 3837     3171.0    152708.0           댄스   0
# 3838      707.0     64019.0           댄스   0
# 3839          0           0          발라드   1
# 3840     3770.0     20260.0     성인가요/트로트   0
# 3841          0           0          POP   0
#
# [3842 rows x 8 columns]

# %%
melon_data['new_category'].value_counts()
# Out:
# 발라드                      1357
# 댄스                        850
# 랩/힙합                      634
# R&B/Soul                  344
# 록/메탈                      201
# POP                        89
# 인디음악, 포크/블루스               69
# 포크/블루스                     58
# 발라드, 인디음악                  33
# 인디음악, 록/메탈                 33
# 일렉트로니카                     24
# 성인가요/트로트                   23
# R&B/Soul, 인디음악             13
# 발라드, R&B/Soul              13
# 랩/힙합, 인디음악                 13
# -                          11
# POP, 국외영화                  10
# POP, 애니메이션/웹툰, 키즈, 만화       9
# 국내드라마                       8
# 발라드, 랩/힙합                   7
# 록/메탈, 국외영화                  6
# 국내영화                        5
# 인디음악, 일렉트로니카                5
# 국외영화                        3
# 발라드, 록/메탈                   3
# 발라드, 국내영화                   3
# 재즈, 애시드/퓨전/팝                2
# 댄스, 랩/힙합                    2
# 뮤직테라피                       2
# 클래식, 크로스오버                  2
# 뉴에이지                        2
# 댄스, 게임                      1
# 월드뮤직, 중국음악                  1
# POP, 록/메탈, 국외영화             1
# POP, 록/메탈                   1
# 댄스, 일렉트로니카                  1
# 발라드, 애니메이션/웹툰, 키즈, 만화       1
# 재즈                          1
# J-POP                       1
# Name: new_category, dtype: int64

# %%
melon_data[melon_data['new_category']=='뮤직테라피']
# Out:
#         music  singer release_date music_like movie_like movie_views  \
# 596  매일 매일 매일  어반 자카파   2020.12.02         29          0           0
# 623        위로  어반 자카파   2021.02.23          0          0           0
#
#     new_category OST
# 596        뮤직테라피   0
# 623        뮤직테라피   0

# %%
melon_data[500:550]
# Out:
#                                       music  \
# 500                      It`s Christmas Day
# 501                                 하나뿐인 사람
# 502                                    청춘연가
# 503                                    마음대로
# 504                      The Christmas Song
# 505                            Jingle Bells
# 506                         White Christmas
# 507              I`ll Be Home For Christmas
# 508                             Sleigh Ride
# 509                                반대로만 살자.
# 510                                     녹여줘
# 511                                      겁나
# 512  Have Yourself A Merry Little Christmas
# 513                                  눈보다 먼저
# 514                             Let It Snow
# 515                                  가리워진 길
# 516                                RE : 나에게
# 517                                   니 말대로
# 518                                대낮에 한 이별
# 519                  Baby It`s Cold Outside
# 520                                      함께
# 521                       Winter Wonderland
# 522                              아무일 없었다는 듯
# 523                                   Angel
# 524                              사랑에 빠지고 싶다
# 525                   Rockin` With The Best
# 526                                첫눈이 온다구요
# 527                           Brand New Day
# 528                                  웃는 것밖에
# 529                                 크리스마스니까
# 530                                     새벽비
# 531                                  Finale
# 532                                    싱숭생숭
# 533                                   울어도 돼
# 534                                  가슴이 뛴다
# 535                                   나쁜 소문
# 536                             Love Is You
# 537                              엄마로 산다는 것은
# 538                                    이리와봐
# 539                                잊지 말기로 해
# 540                              임박사와 함께 춤을
# 541                 Little Apple With 젓가락형제
# 542                                  자꾸 생각나
# 543                                   눈물고드름
# 544                                   날 안아줘
# 545                                    바라보기
# 546                                     지우다
# 547                          봄 여름 가을 그리고...
# 548                                    처음으로
# 549                              Sweet Love
#
#                                                 singer release_date  \
# 500                                                로이킴   2014.12.19
# 501                                                케이윌   2014.12.18
# 502                                                  넬   2014.12.15
# 503                                                이진아   2014.12.14
# 504                                                성시경   2002.11.26
# 505                                                성시경   2014.12.09
# 506                                                성시경   2004.11.24
# 507                                                성시경   2014.12.09
# 508                                                성시경   2014.12.09
# 509                                              V.O.S   2015.03.11
# 510                                                에릭남   2014.12.10
# 511                                              멜로디데이   2014.12.12
# 512                                                성시경   2014.12.09
# 513                                                 칸토   2014.12.11
# 514                                                성시경   2014.12.09
# 515                                             볼빨간사춘기   2014.12.05
# 516                                                 윤상   2014.12.11
# 517                                                김나영   2014.12.09
# 518                                         수지 & 버나드 박   2014.12.09
# 519                                           성시경, 에일리   2014.12.09
# 520                                               인피니트   2014.12.08
# 521                                                성시경   2014.12.09
# 522                                             휘성, 알리   2014.12.09
# 523                                     윤미래, 타이거JK, 비지   2014.12.08
# 524                                                정승환   2014.12.07
# 525                           더 콰이엇, 도끼, 빈지노(Beenzino)   2014.11.28
# 526                                                손승연   2014.12.04
# 527  버벌진트(Verbal Jint), 산이(San E), 팬텀(Phantom), 애즈원...   2014.12.05
# 528                               스탠딩 에그(Standing Egg)   2014.12.05
# 529                             성시경, 박효신, 이석훈, 서인국, 빅스   2012.12.06
# 530                                                 샤넌   2014.12.01
# 531                                             소진, 도끼   2014.12.01
# 532                                       다이나믹 듀오, 박정현   2014.12.05
# 533                                                비투비   2014.12.22
# 534                                              인피니트F   2014.12.01
# 535                                                 지아   2014.12.02
# 536  케이윌(K.will), 씨스타, 정기고(Junggigo), 매드 클라운(Mad Cl...   2014.12.04
# 537                                                이설아   2014.11.30
# 538                                           MASTA WU   2014.12.02
# 539                                           성시경, 권진아   2014.12.09
# 540                                                임창정   2014.11.24
# 541                                                티아라   2014.11.24
# 542                                                 로꼬   2014.11.28
# 543                                                김연우   2014.11.27
# 544                                                 40   2014.11.26
# 545                                              엠씨더맥스   2014.11.28
# 546                                                써니힐   2014.11.27
# 547                                                엠블랙   2014.11.25
# 548                                            신지수, 김필   2014.11.25
# 549                                                백청강   2014.11.27
#
#     music_like movie_like movie_views  new_category OST
# 500      10716      822.0     66327.0        포크/블루스   0
# 501      19826          0           0           발라드   1
# 502      22677      990.0     75828.0          록/메탈   0
# 503      18608          0           0           발라드   0
# 504         28          0           0             -   0
# 505       1440          0           0           발라드   0
# 506       1307          0           0             -   0
# 507       1574          0           0           발라드   0
# 508       1930          0           0           발라드   0
# 509        363          0           0           발라드   0
# 510       9593      426.0     41124.0            댄스   0
# 511       8225      270.0    152551.0           발라드   0
# 512       2847          0           0           발라드   0
# 513       7111      156.0     43884.0          랩/힙합   0
# 514       2659          0           0           발라드   0
# 515      33507          0           0        포크/블루스   1
# 516      16264          0           0           발라드   0
# 517      18089      329.0     90169.0           발라드   0
# 518      18422          0           0           발라드   0
# 519       6590          0           0           발라드   0
# 520      21695     7073.0    144426.0     발라드, 국내영화   0
# 521      53077     1268.0    316050.0           발라드   0
# 522       6175          0           0           발라드   0
# 523      45026     1079.0    462394.0          랩/힙합   0
# 524      99534          0           0           발라드   0
# 525      20697          0           0          랩/힙합   0
# 526       6146      137.0     42421.0           발라드   0
# 527       7420      491.0    103843.0          랩/힙합   0
# 528      10243          0           0  인디음악, 포크/블루스   0
# 529     161997     6712.0    565530.0           발라드   0
# 530      11391      411.0    252007.0            댄스   0
# 531       6948          0           0      R&B/Soul   0
# 532      49775      281.0    213140.0          랩/힙합   0
# 533      58217     5076.0    224311.0            댄스   0
# 534      15708     3661.0    260724.0            댄스   0
# 535       6032      440.0    120337.0           발라드   0
# 536      14900     1785.0    366340.0            댄스   0
# 537      15426          0           0           발라드   0
# 538      18204      597.0    431711.0          랩/힙합   0
# 539      53077     1268.0    316050.0           발라드   0
# 540       2889      750.0    183777.0            댄스   0
# 541       3269      518.0    296508.0            댄스   0
# 542      24220      934.0    272046.0          랩/힙합   0
# 543       7463      191.0     29106.0           발라드   0
# 544       6347       83.0     18546.0      R&B/Soul   0
# 545      71183     1485.0    193216.0           발라드   1
# 546       3201      286.0     84153.0           발라드   0
# 547       2415          0           0           발라드   0
# 548       5961          0           0      R&B/Soul   0
# 549        657      123.0     14841.0           발라드   0

# %%
melon_data.loc[70, 'new_category'] = '록'
melon_data.loc[266, 'new_category'] = '댄스'
melon_data.loc[450, 'new_category'] = '댄스'
melon_data.loc[504, 'new_category'] = '발라드'
melon_data.loc[506, 'new_category'] = '록'

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# le = le.fit(melon_data['new_category'])   #train['col']을 fit
# melon_data['new_category'] = le.transform(melon_data['new_category'])   #train['col']에 따라 encoding
# #test['col'] = le.transform(test['col'])   #train['col']에 따라 encoding

# %%
pd.get_dummies(melon_data['new_category'], dummy_na=True)
